# %%
from bs4 import BeautifulSoup
import requests

# %%
try:
    source= requests.get('https://m.imdb.com/chart/top/')
    source.raise_for_status()
    
    soup = BeautifulSoup(source.text,'html.parser')
    #print(soup.prettify())
    
    movies= soup.find('section', id ="chart-content").find_all('h4')
    #print(len(movies))                      
    
    for movie in movies:
        
        #name =h4.text
        print(movies)
        break
except Exception as e:
    print(e)
# Out:
# [<h4>
# <span class="unbold">1.</span>
# The Shawshank Redemption
# <span class="unbold">(1994)</span>
# </h4>, <h4>
# <span class="unbold">2.</span>
# The Godfather
# <span class="unbold">(1972)</span>
# </h4>, <h4>
# <span class="unbold">3.</span>
# The Dark Knight
# <span class="unbold">(2008)</span>
# </h4>, <h4>
# <span class="unbold">4.</span>
# The Godfather: Part II
# <span class="unbold">(1974)</span>
# </h4>, <h4>
# <span class="unbold">5.</span>
# 12 Angry Men
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">6.</span>
# Schindler's List
# <span class="unbold">(1993)</span>
# </h4>, <h4>
# <span class="unbold">7.</span>
# The Lord of the Rings: The Return of the King
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">8.</span>
# Pulp Fiction
# <span class="unbold">(1994)</span>
# </h4>, <h4>
# <span class="unbold">9.</span>
# The Lord of the Rings: The Fellowship of the Ring
# <span class="unbold">(2001)</span>
# </h4>, <h4>
# <span class="unbold">10.</span>
# The Good, the Bad and the Ugly
# <span class="unbold">(1966)</span>
# </h4>, <h4>
# <span class="unbold">11.</span>
# Forrest Gump
# <span class="unbold">(1994)</span>
# </h4>, <h4>
# <span class="unbold">12.</span>
# Fight Club
# <span class="unbold">(1999)</span>
# </h4>, <h4>
# <span class="unbold">13.</span>
# Inception
# <span class="unbold">(2010)</span>
# </h4>, <h4>
# <span class="unbold">14.</span>
# The Lord of the Rings: The Two Towers
# <span class="unbold">(2002)</span>
# </h4>, <h4>
# <span class="unbold">15.</span>
# Star Wars: Episode V - The Empire Strikes Back
# <span class="unbold">(1980)</span>
# </h4>, <h4>
# <span class="unbold">16.</span>
# The Matrix
# <span class="unbold">(1999)</span>
# </h4>, <h4>
# <span class="unbold">17.</span>
# Goodfellas
# <span class="unbold">(1990)</span>
# </h4>, <h4>
# <span class="unbold">18.</span>
# One Flew Over the Cuckoo's Nest
# <span class="unbold">(1975)</span>
# </h4>, <h4>
# <span class="unbold">19.</span>
# Se7en
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">20.</span>
# Seven Samurai
# <span class="unbold">(1954)</span>
# </h4>, <h4>
# <span class="unbold">21.</span>
# It's a Wonderful Life
# <span class="unbold">(1946)</span>
# </h4>, <h4>
# <span class="unbold">22.</span>
# The Silence of the Lambs
# <span class="unbold">(1991)</span>
# </h4>, <h4>
# <span class="unbold">23.</span>
# Saving Private Ryan
# <span class="unbold">(1998)</span>
# </h4>, <h4>
# <span class="unbold">24.</span>
# City of God
# <span class="unbold">(2002)</span>
# </h4>, <h4>
# <span class="unbold">25.</span>
# Life Is Beautiful
# <span class="unbold">(1997)</span>
# </h4>, <h4>
# <span class="unbold">26.</span>
# The Green Mile
# <span class="unbold">(1999)</span>
# </h4>, <h4>
# <span class="unbold">27.</span>
# Star Wars
# <span class="unbold">(1977)</span>
# </h4>, <h4>
# <span class="unbold">28.</span>
# Interstellar
# <span class="unbold">(2014)</span>
# </h4>, <h4>
# <span class="unbold">29.</span>
# Terminator 2: Judgment Day
# <span class="unbold">(1991)</span>
# </h4>, <h4>
# <span class="unbold">30.</span>
# Back to the Future
# <span class="unbold">(1985)</span>
# </h4>, <h4>
# <span class="unbold">31.</span>
# Spirited Away
# <span class="unbold">(2001)</span>
# </h4>, <h4>
# <span class="unbold">32.</span>
# Psycho
# <span class="unbold">(1960)</span>
# </h4>, <h4>
# <span class="unbold">33.</span>
# Léon: The Professional
# <span class="unbold">(1994)</span>
# </h4>, <h4>
# <span class="unbold">34.</span>
# The Pianist
# <span class="unbold">(2002)</span>
# </h4>, <h4>
# <span class="unbold">35.</span>
# Parasite
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">36.</span>
# The Lion King
# <span class="unbold">(1994)</span>
# </h4>, <h4>
# <span class="unbold">37.</span>
# Gladiator
# <span class="unbold">(2000)</span>
# </h4>, <h4>
# <span class="unbold">38.</span>
# American History X
# <span class="unbold">(1998)</span>
# </h4>, <h4>
# <span class="unbold">39.</span>
# The Usual Suspects
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">40.</span>
# The Departed
# <span class="unbold">(2006)</span>
# </h4>, <h4>
# <span class="unbold">41.</span>
# Spider-Man: No Way Home
# <span class="unbold">(2021)</span>
# </h4>, <h4>
# <span class="unbold">42.</span>
# The Prestige
# <span class="unbold">(2006)</span>
# </h4>, <h4>
# <span class="unbold">43.</span>
# Casablanca
# <span class="unbold">(1942)</span>
# </h4>, <h4>
# <span class="unbold">44.</span>
# Whiplash
# <span class="unbold">(2014)</span>
# </h4>, <h4>
# <span class="unbold">45.</span>
# The Intouchables
# <span class="unbold">(2011)</span>
# </h4>, <h4>
# <span class="unbold">46.</span>
# Modern Times
# <span class="unbold">(1936)</span>
# </h4>, <h4>
# <span class="unbold">47.</span>
# Once Upon a Time in the West
# <span class="unbold">(1968)</span>
# </h4>, <h4>
# <span class="unbold">48.</span>
# Hara-Kiri
# <span class="unbold">(1962)</span>
# </h4>, <h4>
# <span class="unbold">49.</span>
# Grave of the Fireflies
# <span class="unbold">(1988)</span>
# </h4>, <h4>
# <span class="unbold">50.</span>
# Alien
# <span class="unbold">(1979)</span>
# </h4>, <h4>
# <span class="unbold">51.</span>
# Rear Window
# <span class="unbold">(1954)</span>
# </h4>, <h4>
# <span class="unbold">52.</span>
# City Lights
# <span class="unbold">(1931)</span>
# </h4>, <h4>
# <span class="unbold">53.</span>
# Memento
# <span class="unbold">(2000)</span>
# </h4>, <h4>
# <span class="unbold">54.</span>
# Apocalypse Now
# <span class="unbold">(1979)</span>
# </h4>, <h4>
# <span class="unbold">55.</span>
# Cinema Paradiso
# <span class="unbold">(1988)</span>
# </h4>, <h4>
# <span class="unbold">56.</span>
# Indiana Jones and the Raiders of the Lost Ark
# <span class="unbold">(1981)</span>
# </h4>, <h4>
# <span class="unbold">57.</span>
# Django Unchained
# <span class="unbold">(2012)</span>
# </h4>, <h4>
# <span class="unbold">58.</span>
# WALL·E
# <span class="unbold">(2008)</span>
# </h4>, <h4>
# <span class="unbold">59.</span>
# The Lives of Others
# <span class="unbold">(2006)</span>
# </h4>, <h4>
# <span class="unbold">60.</span>
# Sunset Blvd.
# <span class="unbold">(1950)</span>
# </h4>, <h4>
# <span class="unbold">61.</span>
# The Shining
# <span class="unbold">(1980)</span>
# </h4>, <h4>
# <span class="unbold">62.</span>
# Paths of Glory
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">63.</span>
# The Great Dictator
# <span class="unbold">(1940)</span>
# </h4>, <h4>
# <span class="unbold">64.</span>
# Avengers: Infinity War
# <span class="unbold">(2018)</span>
# </h4>, <h4>
# <span class="unbold">65.</span>
# Witness for the Prosecution
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">66.</span>
# Aliens
# <span class="unbold">(1986)</span>
# </h4>, <h4>
# <span class="unbold">67.</span>
# American Beauty
# <span class="unbold">(1999)</span>
# </h4>, <h4>
# <span class="unbold">68.</span>
# The Dark Knight Rises
# <span class="unbold">(2012)</span>
# </h4>, <h4>
# <span class="unbold">69.</span>
# Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb
# <span class="unbold">(1964)</span>
# </h4>, <h4>
# <span class="unbold">70.</span>
# The Batman
# <span class="unbold">(2022)</span>
# </h4>, <h4>
# <span class="unbold">71.</span>
# Joker
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">72.</span>
# Spider-Man: Into the Spider-Verse
# <span class="unbold">(2018)</span>
# </h4>, <h4>
# <span class="unbold">73.</span>
# Old Boy
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">74.</span>
# Braveheart
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">75.</span>
# Toy Story
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">76.</span>
# Amadeus
# <span class="unbold">(1984)</span>
# </h4>, <h4>
# <span class="unbold">77.</span>
# Coco
# <span class="unbold">(2017)</span>
# </h4>, <h4>
# <span class="unbold">78.</span>
# Inglourious Basterds
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">79.</span>
# The Boat
# <span class="unbold">(1981)</span>
# </h4>, <h4>
# <span class="unbold">80.</span>
# Avengers: Endgame
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">81.</span>
# Princess Mononoke
# <span class="unbold">(1997)</span>
# </h4>, <h4>
# <span class="unbold">82.</span>
# Once Upon a Time in America
# <span class="unbold">(1984)</span>
# </h4>, <h4>
# <span class="unbold">83.</span>
# Good Will Hunting
# <span class="unbold">(1997)</span>
# </h4>, <h4>
# <span class="unbold">84.</span>
# Toy Story 3
# <span class="unbold">(2010)</span>
# </h4>, <h4>
# <span class="unbold">85.</span>
# Requiem for a Dream
# <span class="unbold">(2000)</span>
# </h4>, <h4>
# <span class="unbold">86.</span>
# 3 Idiots
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">87.</span>
# Singin' in the Rain
# <span class="unbold">(1952)</span>
# </h4>, <h4>
# <span class="unbold">88.</span>
# Your Name.
# <span class="unbold">(2016)</span>
# </h4>, <h4>
# <span class="unbold">89.</span>
# Star Wars: Episode VI - Return of the Jedi
# <span class="unbold">(1983)</span>
# </h4>, <h4>
# <span class="unbold">90.</span>
# Reservoir Dogs
# <span class="unbold">(1992)</span>
# </h4>, <h4>
# <span class="unbold">91.</span>
# Eternal Sunshine of the Spotless Mind
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">92.</span>
# 2001: A Space Odyssey
# <span class="unbold">(1968)</span>
# </h4>, <h4>
# <span class="unbold">93.</span>
# Citizen Kane
# <span class="unbold">(1941)</span>
# </h4>, <h4>
# <span class="unbold">94.</span>
# High and Low
# <span class="unbold">(1963)</span>
# </h4>, <h4>
# <span class="unbold">95.</span>
# Lawrence of Arabia
# <span class="unbold">(1962)</span>
# </h4>, <h4>
# <span class="unbold">96.</span>
# M
# <span class="unbold">(1931)</span>
# </h4>, <h4>
# <span class="unbold">97.</span>
# Capernaum
# <span class="unbold">(2018)</span>
# </h4>, <h4>
# <span class="unbold">98.</span>
# North by Northwest
# <span class="unbold">(1959)</span>
# </h4>, <h4>
# <span class="unbold">99.</span>
# The Hunt
# <span class="unbold">(2012)</span>
# </h4>, <h4>
# <span class="unbold">100.</span>
# Vertigo
# <span class="unbold">(1958)</span>
# </h4>, <h4>
# <span class="unbold">101.</span>
# Amélie
# <span class="unbold">(2001)</span>
# </h4>, <h4>
# <span class="unbold">102.</span>
# A Clockwork Orange
# <span class="unbold">(1971)</span>
# </h4>, <h4>
# <span class="unbold">103.</span>
# Full Metal Jacket
# <span class="unbold">(1987)</span>
# </h4>, <h4>
# <span class="unbold">104.</span>
# Scarface
# <span class="unbold">(1983)</span>
# </h4>, <h4>
# <span class="unbold">105.</span>
# Double Indemnity
# <span class="unbold">(1944)</span>
# </h4>, <h4>
# <span class="unbold">106.</span>
# Come and See
# <span class="unbold">(1985)</span>
# </h4>, <h4>
# <span class="unbold">107.</span>
# The Apartment
# <span class="unbold">(1960)</span>
# </h4>, <h4>
# <span class="unbold">108.</span>
# Taxi Driver
# <span class="unbold">(1976)</span>
# </h4>, <h4>
# <span class="unbold">109.</span>
# To Kill a Mockingbird
# <span class="unbold">(1962)</span>
# </h4>, <h4>
# <span class="unbold">110.</span>
# Hamilton
# <span class="unbold">(2020)</span>
# </h4>, <h4>
# <span class="unbold">111.</span>
# The Sting
# <span class="unbold">(1973)</span>
# </h4>, <h4>
# <span class="unbold">112.</span>
# L.A. Confidential
# <span class="unbold">(1997)</span>
# </h4>, <h4>
# <span class="unbold">113.</span>
# Up
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">114.</span>
# Heat
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">115.</span>
# Ikiru
# <span class="unbold">(1952)</span>
# </h4>, <h4>
# <span class="unbold">116.</span>
# Snatch
# <span class="unbold">(2000)</span>
# </h4>, <h4>
# <span class="unbold">117.</span>
# Die Hard
# <span class="unbold">(1988)</span>
# </h4>, <h4>
# <span class="unbold">118.</span>
# Indiana Jones and the Last Crusade
# <span class="unbold">(1989)</span>
# </h4>, <h4>
# <span class="unbold">119.</span>
# A Separation
# <span class="unbold">(2011)</span>
# </h4>, <h4>
# <span class="unbold">120.</span>
# Metropolis
# <span class="unbold">(1927)</span>
# </h4>, <h4>
# <span class="unbold">121.</span>
# Bicycle Thieves
# <span class="unbold">(1948)</span>
# </h4>, <h4>
# <span class="unbold">122.</span>
# Incendies
# <span class="unbold">(2010)</span>
# </h4>, <h4>
# <span class="unbold">123.</span>
# 1917
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">124.</span>
# Like Stars on Earth
# <span class="unbold">(2007)</span>
# </h4>, <h4>
# <span class="unbold">125.</span>
# Batman Begins
# <span class="unbold">(2005)</span>
# </h4>, <h4>
# <span class="unbold">126.</span>
# For a Few Dollars More
# <span class="unbold">(1965)</span>
# </h4>, <h4>
# <span class="unbold">127.</span>
# Dangal
# <span class="unbold">(2016)</span>
# </h4>, <h4>
# <span class="unbold">128.</span>
# Downfall
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">129.</span>
# The Kid
# <span class="unbold">(1921)</span>
# </h4>, <h4>
# <span class="unbold">130.</span>
# Some Like It Hot
# <span class="unbold">(1959)</span>
# </h4>, <h4>
# <span class="unbold">131.</span>
# The Father
# <span class="unbold">(2020)</span>
# </h4>, <h4>
# <span class="unbold">132.</span>
# All About Eve
# <span class="unbold">(1950)</span>
# </h4>, <h4>
# <span class="unbold">133.</span>
# Green Book
# <span class="unbold">(2018)</span>
# </h4>, <h4>
# <span class="unbold">134.</span>
# The Wolf of Wall Street
# <span class="unbold">(2013)</span>
# </h4>, <h4>
# <span class="unbold">135.</span>
# Unforgiven
# <span class="unbold">(1992)</span>
# </h4>, <h4>
# <span class="unbold">136.</span>
# Casino
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">137.</span>
# Pan's Labyrinth
# <span class="unbold">(2006)</span>
# </h4>, <h4>
# <span class="unbold">138.</span>
# Judgment at Nuremberg
# <span class="unbold">(1961)</span>
# </h4>, <h4>
# <span class="unbold">139.</span>
# Ran
# <span class="unbold">(1985)</span>
# </h4>, <h4>
# <span class="unbold">140.</span>
# A Beautiful Mind
# <span class="unbold">(2001)</span>
# </h4>, <h4>
# <span class="unbold">141.</span>
# The Sixth Sense
# <span class="unbold">(1999)</span>
# </h4>, <h4>
# <span class="unbold">142.</span>
# Monty Python and the Holy Grail
# <span class="unbold">(1975)</span>
# </h4>, <h4>
# <span class="unbold">143.</span>
# There Will Be Blood
# <span class="unbold">(2007)</span>
# </h4>, <h4>
# <span class="unbold">144.</span>
# The Truman Show
# <span class="unbold">(1998)</span>
# </h4>, <h4>
# <span class="unbold">145.</span>
# Yojimbo
# <span class="unbold">(1961)</span>
# </h4>, <h4>
# <span class="unbold">146.</span>
# The Treasure of the Sierra Madre
# <span class="unbold">(1948)</span>
# </h4>, <h4>
# <span class="unbold">147.</span>
# Shutter Island
# <span class="unbold">(2010)</span>
# </h4>, <h4>
# <span class="unbold">148.</span>
# The Great Escape
# <span class="unbold">(1963)</span>
# </h4>, <h4>
# <span class="unbold">149.</span>
# Rashomon
# <span class="unbold">(1950)</span>
# </h4>, <h4>
# <span class="unbold">150.</span>
# Jurassic Park
# <span class="unbold">(1993)</span>
# </h4>, <h4>
# <span class="unbold">151.</span>
# Kill Bill: Vol. 1
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">152.</span>
# Finding Nemo
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">153.</span>
# No Country for Old Men
# <span class="unbold">(2007)</span>
# </h4>, <h4>
# <span class="unbold">154.</span>
# Raging Bull
# <span class="unbold">(1980)</span>
# </h4>, <h4>
# <span class="unbold">155.</span>
# The Elephant Man
# <span class="unbold">(1980)</span>
# </h4>, <h4>
# <span class="unbold">156.</span>
# V for Vendetta
# <span class="unbold">(2005)</span>
# </h4>, <h4>
# <span class="unbold">157.</span>
# Gone with the Wind
# <span class="unbold">(1939)</span>
# </h4>, <h4>
# <span class="unbold">158.</span>
# Chinatown
# <span class="unbold">(1974)</span>
# </h4>, <h4>
# <span class="unbold">159.</span>
# Inside Out
# <span class="unbold">(2015)</span>
# </h4>, <h4>
# <span class="unbold">160.</span>
# Lock, Stock and Two Smoking Barrels
# <span class="unbold">(1998)</span>
# </h4>, <h4>
# <span class="unbold">161.</span>
# The Thing
# <span class="unbold">(1982)</span>
# </h4>, <h4>
# <span class="unbold">162.</span>
# Dial M for Murder
# <span class="unbold">(1954)</span>
# </h4>, <h4>
# <span class="unbold">163.</span>
# The Secret in Their Eyes
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">164.</span>
# Howl's Moving Castle
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">165.</span>
# The Bridge on the River Kwai
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">166.</span>
# Trainspotting
# <span class="unbold">(1996)</span>
# </h4>, <h4>
# <span class="unbold">167.</span>
# Three Billboards Outside Ebbing, Missouri
# <span class="unbold">(2017)</span>
# </h4>, <h4>
# <span class="unbold">168.</span>
# Warrior
# <span class="unbold">(2011)</span>
# </h4>, <h4>
# <span class="unbold">169.</span>
# Gran Torino
# <span class="unbold">(2008)</span>
# </h4>, <h4>
# <span class="unbold">170.</span>
# Fargo
# <span class="unbold">(1996)</span>
# </h4>, <h4>
# <span class="unbold">171.</span>
# My Neighbor Totoro
# <span class="unbold">(1988)</span>
# </h4>, <h4>
# <span class="unbold">172.</span>
# Prisoners
# <span class="unbold">(2013)</span>
# </h4>, <h4>
# <span class="unbold">173.</span>
# Million Dollar Baby
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">174.</span>
# Blade Runner
# <span class="unbold">(1982)</span>
# </h4>, <h4>
# <span class="unbold">175.</span>
# The Gold Rush
# <span class="unbold">(1925)</span>
# </h4>, <h4>
# <span class="unbold">176.</span>
# Catch Me If You Can
# <span class="unbold">(2002)</span>
# </h4>, <h4>
# <span class="unbold">177.</span>
# On the Waterfront
# <span class="unbold">(1954)</span>
# </h4>, <h4>
# <span class="unbold">178.</span>
# Children of Heaven
# <span class="unbold">(1997)</span>
# </h4>, <h4>
# <span class="unbold">179.</span>
# Harry Potter and the Deathly Hallows: Part 2
# <span class="unbold">(2011)</span>
# </h4>, <h4>
# <span class="unbold">180.</span>
# The Third Man
# <span class="unbold">(1949)</span>
# </h4>, <h4>
# <span class="unbold">181.</span>
# Gone Girl
# <span class="unbold">(2014)</span>
# </h4>, <h4>
# <span class="unbold">182.</span>
# Ben-Hur
# <span class="unbold">(1959)</span>
# </h4>, <h4>
# <span class="unbold">183.</span>
# 12 Years a Slave
# <span class="unbold">(2013)</span>
# </h4>, <h4>
# <span class="unbold">184.</span>
# The General
# <span class="unbold">(1926)</span>
# </h4>, <h4>
# <span class="unbold">185.</span>
# The Deer Hunter
# <span class="unbold">(1978)</span>
# </h4>, <h4>
# <span class="unbold">186.</span>
# Wild Strawberries
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">187.</span>
# Before Sunrise
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">188.</span>
# In the Name of the Father
# <span class="unbold">(1993)</span>
# </h4>, <h4>
# <span class="unbold">189.</span>
# Pather Panchali
# <span class="unbold">(1955)</span>
# </h4>, <h4>
# <span class="unbold">190.</span>
# Mr. Smith Goes to Washington
# <span class="unbold">(1939)</span>
# </h4>, <h4>
# <span class="unbold">191.</span>
# The Grand Budapest Hotel
# <span class="unbold">(2014)</span>
# </h4>, <h4>
# <span class="unbold">192.</span>
# Room
# <span class="unbold">(2015)</span>
# </h4>, <h4>
# <span class="unbold">193.</span>
# Sherlock Jr.
# <span class="unbold">(1924)</span>
# </h4>, <h4>
# <span class="unbold">194.</span>
# Hacksaw Ridge
# <span class="unbold">(2016)</span>
# </h4>, <h4>
# <span class="unbold">195.</span>
# How to Train Your Dragon
# <span class="unbold">(2010)</span>
# </h4>, <h4>
# <span class="unbold">196.</span>
# The Wages of Fear
# <span class="unbold">(1953)</span>
# </h4>, <h4>
# <span class="unbold">197.</span>
# Memories of Murder
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">198.</span>
# The Seventh Seal
# <span class="unbold">(1957)</span>
# </h4>, <h4>
# <span class="unbold">199.</span>
# Barry Lyndon
# <span class="unbold">(1975)</span>
# </h4>, <h4>
# <span class="unbold">200.</span>
# The Big Lebowski
# <span class="unbold">(1998)</span>
# </h4>, <h4>
# <span class="unbold">201.</span>
# Klaus
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">202.</span>
# Mad Max: Fury Road
# <span class="unbold">(2015)</span>
# </h4>, <h4>
# <span class="unbold">203.</span>
# Wild Tales
# <span class="unbold">(2014)</span>
# </h4>, <h4>
# <span class="unbold">204.</span>
# Monsters, Inc.
# <span class="unbold">(2001)</span>
# </h4>, <h4>
# <span class="unbold">205.</span>
# Mary and Max
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">206.</span>
# Jaws
# <span class="unbold">(1975)</span>
# </h4>, <h4>
# <span class="unbold">207.</span>
# The Passion of Joan of Arc
# <span class="unbold">(1928)</span>
# </h4>, <h4>
# <span class="unbold">208.</span>
# Hotel Rwanda
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">209.</span>
# Rocky
# <span class="unbold">(1976)</span>
# </h4>, <h4>
# <span class="unbold">210.</span>
# Dead Poets Society
# <span class="unbold">(1989)</span>
# </h4>, <h4>
# <span class="unbold">211.</span>
# Tokyo Story
# <span class="unbold">(1953)</span>
# </h4>, <h4>
# <span class="unbold">212.</span>
# Platoon
# <span class="unbold">(1986)</span>
# </h4>, <h4>
# <span class="unbold">213.</span>
# Ford v Ferrari
# <span class="unbold">(2019)</span>
# </h4>, <h4>
# <span class="unbold">214.</span>
# The Terminator
# <span class="unbold">(1984)</span>
# </h4>, <h4>
# <span class="unbold">215.</span>
# Stand by Me
# <span class="unbold">(1986)</span>
# </h4>, <h4>
# <span class="unbold">216.</span>
# Rush
# <span class="unbold">(2013)</span>
# </h4>, <h4>
# <span class="unbold">217.</span>
# Into the Wild
# <span class="unbold">(2007)</span>
# </h4>, <h4>
# <span class="unbold">218.</span>
# The Wizard of Oz
# <span class="unbold">(1939)</span>
# </h4>, <h4>
# <span class="unbold">219.</span>
# Logan
# <span class="unbold">(2017)</span>
# </h4>, <h4>
# <span class="unbold">220.</span>
# Spotlight
# <span class="unbold">(2015)</span>
# </h4>, <h4>
# <span class="unbold">221.</span>
# Network
# <span class="unbold">(1976)</span>
# </h4>, <h4>
# <span class="unbold">222.</span>
# Groundhog Day
# <span class="unbold">(1993)</span>
# </h4>, <h4>
# <span class="unbold">223.</span>
# The Exorcist
# <span class="unbold">(1973)</span>
# </h4>, <h4>
# <span class="unbold">224.</span>
# Ratatouille
# <span class="unbold">(2007)</span>
# </h4>, <h4>
# <span class="unbold">225.</span>
# Hachi: A Dog's Tale
# <span class="unbold">(2009)</span>
# </h4>, <h4>
# <span class="unbold">226.</span>
# The Incredibles
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">227.</span>
# Dersu Uzala
# <span class="unbold">(1975)</span>
# </h4>, <h4>
# <span class="unbold">228.</span>
# The Best Years of Our Lives
# <span class="unbold">(1946)</span>
# </h4>, <h4>
# <span class="unbold">229.</span>
# Before Sunset
# <span class="unbold">(2004)</span>
# </h4>, <h4>
# <span class="unbold">230.</span>
# Rebecca
# <span class="unbold">(1940)</span>
# </h4>, <h4>
# <span class="unbold">231.</span>
# Dune
# <span class="unbold">(2021)</span>
# </h4>, <h4>
# <span class="unbold">232.</span>
# The Grapes of Wrath
# <span class="unbold">(1940)</span>
# </h4>, <h4>
# <span class="unbold">233.</span>
# My Father and My Son
# <span class="unbold">(2005)</span>
# </h4>, <h4>
# <span class="unbold">234.</span>
# Cool Hand Luke
# <span class="unbold">(1967)</span>
# </h4>, <h4>
# <span class="unbold">235.</span>
# To Be or Not to Be
# <span class="unbold">(1942)</span>
# </h4>, <h4>
# <span class="unbold">236.</span>
# The Battle of Algiers
# <span class="unbold">(1966)</span>
# </h4>, <h4>
# <span class="unbold">237.</span>
# Amores perros
# <span class="unbold">(2000)</span>
# </h4>, <h4>
# <span class="unbold">238.</span>
# Pirates of the Caribbean: The Curse of the Black Pearl
# <span class="unbold">(2003)</span>
# </h4>, <h4>
# <span class="unbold">239.</span>
# The Sound of Music
# <span class="unbold">(1965)</span>
# </h4>, <h4>
# <span class="unbold">240.</span>
# Life of Brian
# <span class="unbold">(1979)</span>
# </h4>, <h4>
# <span class="unbold">241.</span>
# The 400 Blows
# <span class="unbold">(1959)</span>
# </h4>, <h4>
# <span class="unbold">242.</span>
# Persona
# <span class="unbold">(1966)</span>
# </h4>, <h4>
# <span class="unbold">243.</span>
# It Happened One Night
# <span class="unbold">(1934)</span>
# </h4>, <h4>
# <span class="unbold">244.</span>
# La Haine
# <span class="unbold">(1995)</span>
# </h4>, <h4>
# <span class="unbold">245.</span>
# Aladdin
# <span class="unbold">(1992)</span>
# </h4>, <h4>
# <span class="unbold">246.</span>
# Beauty and the Beast
# <span class="unbold">(1991)</span>
# </h4>, <h4>
# <span class="unbold">247.</span>
# Jai Bhim
# <span class="unbold">(2021)</span>
# </h4>, <h4>
# <span class="unbold">248.</span>
# Gandhi
# <span class="unbold">(1982)</span>
# </h4>, <h4>
# <span class="unbold">249.</span>
# The Help
# <span class="unbold">(2011)</span>
# </h4>, <h4>
# <span class="unbold">250.</span>
# The Handmaiden
# <span class="unbold">(2016)</span>
# </h4>]
